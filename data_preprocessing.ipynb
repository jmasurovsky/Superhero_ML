# %%
import pandas as pd
import numpy as np

# %%
#Read in datasets
ability_stats = pd.read_csv("charcters_stats.csv")
ability_matrix = pd.read_csv("superheroes_power_matrix.csv")
info_df = pd.read_csv("marvel_characters_info.csv")

# %%
superhero_df_merged = pd.read_csv("superhero_df_merged.csv")

# %%
#Get dummy values and drop first value keeping only true
df_dummies = pd.get_dummies(superhero_df_merged, 
    columns=[
        'Agility',
 'Accelerated Healing',
 'Lantern Power Ring',
 'Dimensional Awareness',
 'Cold Resistance',
 'Durability_y',
 'Stealth',
 'Energy Absorption',
 'Flight',
 'Danger Sense',
 'Underwater breathing',
 'Marksmanship',
 'Weapons Master',
 'Power Augmentation',
 'Animal Attributes',
 'Longevity',
 'Intelligence_y',
 'Super Strength',
 'Cryokinesis',
 'Telepathy',
 'Energy Armor',
 'Energy Blasts',
 'Duplication',
 'Size Changing',
 'Density Control',
 'Stamina',
 'Astral Travel',
 'Audio Control',
 'Dexterity',
 'Omnitrix',
 'Super Speed',
 'Possession',
 'Animal Oriented Powers',
 'Weapon-based Powers',
 'Electrokinesis',
 'Darkforce Manipulation',
 'Death Touch',
 'Teleportation',
 'Enhanced Senses',
 'Telekinesis',
 'Energy Beams',
 'Magic',
 'Hyperkinesis',
 'Jump',
 'Clairvoyance',
 'Dimensional Travel',
 'Power Sense',
 'Shapeshifting',
 'Peak Human Condition',
 'Immortality',
 'Camouflage',
 'Element Control',
 'Phasing',
 'Astral Projection',
 'Electrical Transport',
 'Fire Control',
 'Projection',
 'Summoning',
 'Enhanced Memory',
 'Reflexes',
 'Invulnerability',
 'Energy Constructs',
 'Force Fields',
 'Self-Sustenance',
 'Anti-Gravity',
 'Empathy',
 'Power Nullifier',
 'Radiation Control',
 'Psionic Powers',
 'Elasticity',
 'Substance Secretion',
 'Elemental Transmogrification',
 'Technopath/Cyberpath',
 'Photographic Reflexes',
 'Seismic Power',
 'Animation',
 'Precognition',
 'Mind Control',
 'Fire Resistance',
 'Power Absorption',
 'Enhanced Hearing',
 'Nova Force',
 'Insanity',
 'Hypnokinesis',
 'Animal Control',
 'Natural Armor',
 'Intangibility',
 'Enhanced Sight',
 'Molecular Manipulation',
 'Heat Generation',
 'Adaptation',
 'Gliding',
 'Power Suit',
 'Mind Blast',
 'Probability Manipulation',
 'Gravity Control',
 'Regeneration',
 'Light Control',
 'Echolocation',
 'Levitation',
 'Toxin and Disease Control',
 'Banish',
 'Energy Manipulation',
 'Heat Resistance',
 'Natural Weapons',
 'Time Travel',
 'Enhanced Smell',
 'Illusions',
 'Thirstokinesis',
 'Hair Manipulation',
 'Illumination',
 'Omnipotent',
 'Cloaking',
 'Changing Armor',
 'Power Cosmic',
 'Biokinesis',
 'Water Control',
 'Radiation Immunity',
 'Vision - Telescopic',
 'Toxin and Disease Resistance',
 'Spatial Awareness',
 'Energy Resistance',
 'Telepathy Resistance',
 'Molecular Combustion',
 'Omnilingualism',
 'Portal Creation',
 'Magnetism',
 'Mind Control Resistance',
 'Plant Control',
 'Sonar',
 'Sonic Scream',
 'Time Manipulation',
 'Enhanced Touch',
 'Magic Resistance',
 'Invisibility',
 'Sub-Mariner',
 'Radiation Absorption',
 'Intuitive aptitude',
 'Vision - Microscopic',
 'Melting',
 'Wind Control',
 'Super Breath',
 'Wallcrawling',
 'Vision - Night',
 'Vision - Infrared',
 'Grim Reaping',
 'Matter Absorption',
 'The Force',
 'Resurrection',
 'Terrakinesis',
 'Vision - Heat',
 'Vitakinesis',
 'Radar Sense',
 'Qwardian Power Ring',
 'Weather Control',
 'Vision - X-Ray',
 'Vision - Thermal',
 'Web Creation',
 'Reality Warping',
 'Odin Force',
 'Symbiote Costume',
 'Speed Force',
 'Phoenix Force',
 'Molecular Dissipation',
 'Vision - Cryo',
 'Omnipresent',
 'Omniscient'],drop_first=True)

# %%
del df_dummies['Unnamed: 0']
df_dummies
# Out:
#                 Name  Alignment  Intelligence  Strength  Speed  Durability  \
# 0             A-Bomb          1            38       100     17          80
# 1         Abe Sapien          1            88        14     35          42
# 2           Abin Sur          1            50        90     53          64
# 3        Abomination          0            63        80     53          90
# 4            Abraxas          0            88       100     83          99
# ..               ...        ...           ...       ...    ...         ...
# 512      Wonder Girl          1            75        90     25          80
# 513     Wonder Woman          1            88       100     50         100
# 514             X-23          1            75        24     35          90
# 515  Yellowjacket II          1            50        10     35          28
# 516          Zatanna          1            75        10     23          28
#
#      Power  Combat  Total  Gender  ... Vision - X-Ray_True  \
# ...

# %%
df_dummies['Gender'] = df_dummies['Gender'].map({'Male': 1, 'Female': 0})

# %%
df_dummies['Height'] = abs(df_dummies['Height'])
df_dummies['Weight'] = abs(df_dummies['Weight'])
df_dummies['BMI'] = abs(df_dummies['BMI'])
df_dummies
# Out:
#                 Name  Alignment  Intelligence  Strength  Speed  Durability  \
# 0             A-Bomb          1            38       100     17          80
# 1         Abe Sapien          1            88        14     35          42
# 2           Abin Sur          1            50        90     53          64
# 3        Abomination          0            63        80     53          90
# 4            Abraxas          0            88       100     83          99
# ..               ...        ...           ...       ...    ...         ...
# 512      Wonder Girl          1            75        90     25          80
# 513     Wonder Woman          1            88       100     50         100
# 514             X-23          1            75        24     35          90
# 515  Yellowjacket II          1            50        10     35          28
# 516          Zatanna          1            75        10     23          28
#
#      Power  Combat  Total  Gender  ... Vision - X-Ray_True  \
# ...

# %%
df_dummies = pd.get_dummies(df_dummies, 
    columns=['SkinColor',
             'EyeColor',
             'HairColor',
             'Race',
            'Publisher'])

# %%
df_dummies
# Out:
#                 Name  Alignment  Intelligence  Strength  Speed  Durability  \
# 0             A-Bomb          1            38       100     17          80
# 1         Abe Sapien          1            88        14     35          42
# 2           Abin Sur          1            50        90     53          64
# 3        Abomination          0            63        80     53          90
# 4            Abraxas          0            88       100     83          99
# ..               ...        ...           ...       ...    ...         ...
# 512      Wonder Girl          1            75        90     25          80
# 513     Wonder Woman          1            88       100     50         100
# 514             X-23          1            75        24     35          90
# 515  Yellowjacket II          1            50        10     35          28
# 516          Zatanna          1            75        10     23          28
#
#      Power  Combat  Total  Gender  ...  Publisher_Image Comics  \
# ...

# %%
df_dummies = df_dummies.drop_duplicates(subset=['Name'])

# %%
df_dummies.to_csv("Character_abilities.csv")

# %%
#Move table to SQL
from sqlalchemy import create_engine
from config import db_password

# %%
db_string = f"postgres://postgres:{db_password}@127.0.0.1:5432/SuperheroDB"

engine = create_engine(db_string)

df_dummies.to_sql(name='Superhero_dummies', con=engine)

# %%
#testing to see if duplicate was removed
df_dummies.loc[df_dummies['Name'] == 'Nova']
# Out:
#      Name  Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 268  Nova          1           100        85     67         101    100
#
#      Combat  Total  Gender  ...  Publisher_Image Comics  \
# 268      85    538       1  ...                       0
#
#      Publisher_Marvel Comics  Publisher_Microsoft  Publisher_NBC - Heroes  \
# 268                        1                    0                       0
#
#      Publisher_Shueisha  Publisher_Sony Pictures  Publisher_SyFy  \
# 268                   0                        0               0
#
#      Publisher_Team Epic TV  Publisher_Universal Studios  Publisher_Wildstorm
# 268                       0                            0                    0
#
# [1 rows x 295 columns]

# %%
df_dummies.loc[df_dummies['Name']=='Toxin']
# Out:
#       Name  Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 352  Toxin          1            56        73     70          84     75
#
#      Combat  Total  Gender  ...  Publisher_Image Comics  \
# 352      70    428       1  ...                       0
#
#      Publisher_Marvel Comics  Publisher_Microsoft  Publisher_NBC - Heroes  \
# 352                        1                    0                       0
#
#      Publisher_Shueisha  Publisher_Sony Pictures  Publisher_SyFy  \
# 352                   0                        0               0
#
#      Publisher_Team Epic TV  Publisher_Universal Studios  Publisher_Wildstorm
# 352                       0                            0                    0
#
# [1 rows x 295 columns]

# %% [markdown]
# # LabelEncode Ability Stats

# %% [markdown]
# ## Strength

# %%
fig, ax = plt.subplots()
df_dummies['Strength'].hist(bins=10, color='#A9C5D3', 
                             edgecolor='black', grid=False)
ax.set_title('Character Strength Histogram', fontsize=12)
ax.set_xlabel('Strength', fontsize=12)
ax.set_ylabel('Frequency', fontsize=12)
# Out:
# Text(0, 0.5, 'Frequency')

# %%
quantile_list = [0, .25, .5, .75, 1.]
quantiles = df_dummies['Strength'].quantile(quantile_list)
quantiles
# Out:
# 0.00      1.0
# 0.25     10.0
# 0.50     14.0
# 0.75     63.0
# 1.00    100.0
# Name: Strength, dtype: float64

# %%
fig, ax = plt.subplots()
df_dummies['Strength'].hist(bins=10, color='#A9C5D3', 
                             edgecolor='black', grid=False)
for quantile in quantiles:
    qvl = plt.axvline(quantile, color='r')
ax.legend([qvl], ['Quantiles'], fontsize=10)
ax.set_title('Character Strength Histogram with Quantiles', 
             fontsize=12)
ax.set_xlabel('Strength', fontsize=12)
ax.set_ylabel('Frequency', fontsize=12)
# Out:
# Text(0, 0.5, 'Frequency')

# %%
quantile_labels = ['0-25Q', '25-50Q', '50-75Q', '75-100Q']
df_dummies['Strength_quantile_range'] = pd.qcut(
                                            df_dummies['Strength'], 
                                            q=quantile_list)
df_dummies['Strength_quantile_label'] = pd.qcut(
                                            df_dummies['Strength'], 
                                            q=quantile_list,       
                                            labels=quantile_labels)

# %%
# transform and map pokemon generations
from sklearn.preprocessing import LabelEncoder

gen_le = LabelEncoder()
gen_labels = gen_le.fit_transform(df_dummies['Strength_quantile_label'])
df_dummies['Strength_Gen_Label'] = gen_labels

# %% [markdown]
# ## Intelligence

# %%
fig, ax = plt.subplots()
df_dummies['Intelligence'].hist(bins=10, color='#A9C5D3', 
                             edgecolor='black', grid=False)
ax.set_title('Character Intelligence Histogram', fontsize=12)
ax.set_xlabel('Intelligence', fontsize=12)
ax.set_ylabel('Frequency', fontsize=12)
# Out:
# Text(0, 0.5, 'Frequency')

# %%
quantile_list = [0, .25, .5, .75, 1.]
quantiles = df_dummies['Intelligence'].quantile(quantile_list)
quantiles
# Out:
# 0.00      1.0
# 0.25     38.0
# 0.50     50.0
# 0.75     75.0
# 1.00    113.0
# Name: Intelligence, dtype: float64

# %%
fig, ax = plt.subplots()
df_dummies['Intelligence'].hist(bins=10, color='#A9C5D3', 
                             edgecolor='black', grid=False)
for quantile in quantiles:
    qvl = plt.axvline(quantile, color='r')
ax.legend([qvl], ['Quantiles'], fontsize=10)
ax.set_title('Character Intelligence Histogram with Quantiles', 
             fontsize=12)
ax.set_xlabel('Intelligence', fontsize=12)
ax.set_ylabel('Frequency', fontsize=12)
# Out:
# Text(0, 0.5, 'Frequency')

# %%
quantile_labels = ['0-25Q', '25-50Q', '50-75Q', '75-100Q']
df_dummies['Intelligence_quantile_range'] = pd.qcut(
                                            df_dummies['Intelligence'], 
                                            q=quantile_list)
df_dummies['Intelligence_quantile_label'] = pd.qcut(
                                            df_dummies['Intelligence'], 
                                            q=quantile_list,       
                                            labels=quantile_labels)

# %%
# transform and map pokemon generations
from sklearn.preprocessing import LabelEncoder

gen_le = LabelEncoder()
gen_labels = gen_le.fit_transform(df_dummies['Intelligence_quantile_label'])
df_dummies['Intelligence_Gen_Label'] = gen_labels

# %% [markdown]
# ## Speed

# %%
fig, ax = plt.subplots()
df_dummies['Speed'].hist(bins=10, color='#A9C5D3', 
                             edgecolor='black', grid=False)
ax.set_title('Character Speed Histogram', fontsize=12)
ax.set_xlabel('Speed', fontsize=12)
ax.set_ylabel('Frequency', fontsize=12)
# Out:
# Text(0, 0.5, 'Frequency')

# %%
quantile_list = [0, .25, .5, .75, 1.]
quantiles = df_dummies['Speed'].quantile(quantile_list)
quantiles
# Out:
# 0.00      1.0
# 0.25     12.0
# 0.50     25.0
# 0.75     47.0
# 1.00    100.0
# Name: Speed, dtype: float64

# %%
fig, ax = plt.subplots()
df_dummies['Speed'].hist(bins=10, color='#A9C5D3', 
                             edgecolor='black', grid=False)
for quantile in quantiles:
    qvl = plt.axvline(quantile, color='r')
ax.legend([qvl], ['Quantiles'], fontsize=10)
ax.set_title('Character Speed Histogram with Quantiles', 
             fontsize=12)
ax.set_xlabel('Speed', fontsize=12)
ax.set_ylabel('Frequency', fontsize=12)
# Out:
# Text(0, 0.5, 'Frequency')

# %%
quantile_labels = ['0-25Q', '25-50Q', '50-75Q', '75-100Q']
df_dummies['Speed_quantile_range'] = pd.qcut(
                                            df_dummies['Speed'], 
                                            q=quantile_list)
df_dummies['Speed_quantile_label'] = pd.qcut(
                                            df_dummies['Speed'], 
                                            q=quantile_list,       
                                            labels=quantile_labels)

# %%
# transform and map pokemon generations
from sklearn.preprocessing import LabelEncoder

gen_le = LabelEncoder()
gen_labels = gen_le.fit_transform(df_dummies['Speed_quantile_label'])
df_dummies['Speed_Gen_Label'] = gen_labels

# %% [markdown]
# ## Power

# %%
fig, ax = plt.subplots()
df_dummies['Power'].hist(bins=10, color='#A9C5D3', 
                             edgecolor='black', grid=False)
ax.set_title('Character Power Histogram', fontsize=12)
ax.set_xlabel('Power', fontsize=12)
ax.set_ylabel('Frequency', fontsize=12)
# Out:
# Text(0, 0.5, 'Frequency')

# %%
quantile_list = [0, .25, .5, .75, 1.]
quantiles = df_dummies['Power'].quantile(quantile_list)
quantiles
# Out:
# 0.00      0.0
# 0.25     19.0
# 0.50     46.0
# 0.75     71.0
# 1.00    100.0
# Name: Power, dtype: float64

# %%
fig, ax = plt.subplots()
df_dummies['Power'].hist(bins=10, color='#A9C5D3', 
                             edgecolor='black', grid=False)
for quantile in quantiles:
    qvl = plt.axvline(quantile, color='r')
ax.legend([qvl], ['Quantiles'], fontsize=10)
ax.set_title('Character Power Histogram with Quantiles', 
             fontsize=12)
ax.set_xlabel('Power', fontsize=12)
ax.set_ylabel('Frequency', fontsize=12)
# Out:
# Text(0, 0.5, 'Frequency')

# %%
quantile_labels = ['0-25Q', '25-50Q', '50-75Q', '75-100Q']
df_dummies['Power_quantile_range'] = pd.qcut(
                                            df_dummies['Power'], 
                                            q=quantile_list)
df_dummies['Power_quantile_label'] = pd.qcut(
                                            df_dummies['Power'], 
                                            q=quantile_list,       
                                            labels=quantile_labels)

# %%
# transform and map generations
from sklearn.preprocessing import LabelEncoder

gen_le = LabelEncoder()
gen_labels = gen_le.fit_transform(df_dummies['Power_quantile_label'])
df_dummies['Power_Gen_Label'] = gen_labels

# %% [markdown]
# ## Combat

# %%
fig, ax = plt.subplots()
df_dummies['Combat'].hist(bins=10, color='#A9C5D3', 
                             edgecolor='black', grid=False)
ax.set_title('Character Combat Histogram', fontsize=12)
ax.set_xlabel('Combat', fontsize=12)
ax.set_ylabel('Frequency', fontsize=12)
# Out:
# Text(0, 0.5, 'Frequency')

# %%
quantile_list = [0, .25, .5, .75, 1.]
quantiles = df_dummies['Combat'].quantile(quantile_list)
quantiles
# Out:
# 0.00      1.0
# 0.25     28.0
# 0.50     56.0
# 0.75     74.0
# 1.00    101.0
# Name: Combat, dtype: float64

# %%
fig, ax = plt.subplots()
df_dummies['Combat'].hist(bins=10, color='#A9C5D3', 
                             edgecolor='black', grid=False)
for quantile in quantiles:
    qvl = plt.axvline(quantile, color='r')
ax.legend([qvl], ['Quantiles'], fontsize=10)
ax.set_title('Character Combat Histogram with Quantiles', 
             fontsize=12)
ax.set_xlabel('Combat', fontsize=12)
ax.set_ylabel('Frequency', fontsize=12)
# Out:
# Text(0, 0.5, 'Frequency')

# %%
quantile_labels = ['0-25Q', '25-50Q', '50-75Q', '75-100Q']
df_dummies['Combat_quantile_range'] = pd.qcut(
                                            df_dummies['Combat'], 
                                            q=quantile_list)
df_dummies['Combat_quantile_label'] = pd.qcut(
                                            df_dummies['Combat'], 
                                            q=quantile_list,       
                                            labels=quantile_labels)

# %%
# transform and map pokemon generations
from sklearn.preprocessing import LabelEncoder

gen_le = LabelEncoder()
gen_labels = gen_le.fit_transform(df_dummies['Combat_quantile_label'])
df_dummies['Combat_Gen_Label'] = gen_labels

# %%
df_dummies.head()
# Out:
#           Name  Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0       A-Bomb          1            38       100     17          80     17
# 1   Abe Sapien          1            88        14     35          42     35
# 2     Abin Sur          1            50        90     53          64     84
# 3  Abomination          0            63        80     53          90     55
# 4      Abraxas          0            88       100     83          99    100
#
#    Combat  Total  Gender  ...  Intelligence_Gen_Label  Speed_quantile_range  \
# 0      64    316       1  ...                       0          (12.0, 25.0]
# 1      85    299       1  ...                       3          (25.0, 47.0]
# 2      65    406       1  ...                       1         (47.0, 100.0]
# 3      95    436       1  ...                       2         (47.0, 100.0]
# 4      56    526       1  ...                       3         (47.0, 100.0]
#
# ...

# %%
model_data_df = df_dummies.drop(columns=['Intelligence',
 'Strength',
 'Speed',
 'Power',
 'Combat',
 'Strength_quantile_range',
 'Strength_quantile_label',
'Intelligence_quantile_range',
 'Intelligence_quantile_label',
        'Speed_quantile_range',
 'Speed_quantile_label',
            'Power_quantile_range',
 'Power_quantile_label',
                 'Combat_quantile_range',
 'Combat_quantile_label'   ])

# %%
model_data_df.head()
# Out:
#           Name  Alignment  Durability  Total  Gender    Height    Weight  \
# 0       A-Bomb          1          80    316       1  6.660105  972.2286
# 1   Abe Sapien          1          42    299       1  6.266404  143.2990
# 2     Abin Sur          1          64    406       1  6.069554  198.4140
# 3  Abomination          0          90    436       1  6.660105  972.2286
# 4      Abraxas          0          99    526       1  3.248031  218.2554
#
#          BMI  Agility_True  Accelerated Healing_True  ...  \
# 0  21.918268             0                         1  ...
# 1   3.649273             1                         1  ...
# 2   5.385906             0                         0  ...
# 3  21.918268             0                         1  ...
# 4  20.688287             0                         0  ...
#
#    Publisher_Sony Pictures  Publisher_SyFy  Publisher_Team Epic TV  \
# 0                        0               0                       0
# ...

# %%
model_data_df.describe()
# Out:
#         Alignment  Durability       Total      Gender      Height  \
# count  517.000000  517.000000  517.000000  517.000000  517.000000
# mean     0.682785   47.876209  257.512573    0.733075    5.484841
# std      0.465843   35.752218  157.244004    0.442781    2.245842
# min      0.000000    1.000000    5.000000    0.000000    0.498688
# 25%      0.000000   14.000000  171.000000    0.000000    4.002625
# 50%      1.000000   42.000000  276.000000    1.000000    5.839895
# 75%      1.000000   84.000000  369.000000    1.000000    6.167979
# max      1.000000  120.000000  581.000000    1.000000   31.988189
#
#             Weight         BMI  Agility_True  Accelerated Healing_True  \
# count   517.000000  517.000000    517.000000                517.000000
# mean    247.286187   11.830116      0.317215                  0.249516
# std     216.169228   28.715307      0.465843                  0.433152
# min       4.409200    0.016672      0.000000                  0.000000
# ...

# %%
list(model_data_df.columns)
# Out:
# ['Name',
#  'Alignment',
#  'Gender',
#  'Height',
#  'Weight',
#  'BMI',
#  'Agility_True',
#  'Accelerated Healing_True',
#  'Lantern Power Ring_True',
#  'Dimensional Awareness_True',
#  'Cold Resistance_True',
#  'Durability_y_True',
#  'Stealth_True',
#  'Energy Absorption_True',
#  'Flight_True',
#  'Danger Sense_True',
#  'Underwater breathing_True',
#  'Marksmanship_True',
#  'Weapons Master_True',
#  'Power Augmentation_True',
#  'Animal Attributes_True',
#  'Longevity_True',
#  'Intelligence_y_True',
#  'Super Strength_True',
#  'Cryokinesis_True',
#  'Telepathy_True',
#  'Energy Armor_True',
#  'Energy Blasts_True',
#  'Duplication_True',
#  'Size Changing_True',
#  'Density Control_True',
#  'Stamina_True',
#  'Astral Travel_True',
#  'Audio Control_True',
#  'Dexterity_True',
#  'Omnitrix_True',
#  'Super Speed_True',
#  'Possession_True',
#  'Animal Oriented Powers_True',
#  'Weapon-based Powers_True',
#  'Electrokinesis_True',
#  'Darkforce Manipulation_True',
# ...

# %%
model_data_df.to_csv('Superhero_model_ready_df.csv')

# %%
db_string = f"postgres://postgres:{db_password}@127.0.0.1:5432/SuperheroDB"

engine = create_engine(db_string)

df_dummies.to_sql(name='Superhero_dummies', con=engine)

# %% [markdown]
# ## Logistic Regression Classification

# %%
y = model_data_df["Alignment"]
X = model_data_df.drop(columns=['Alignment','Name'])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    random_state=1,
                                                   stratify=y)
X_train.shape
# Out:
# (400, 293)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver='lbfgs',
                                max_iter=200,
                                random_state=1)

# %%
classifier.fit(X_train, y_train)
# Out:
# /Users/jasonmasurovsky/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=200,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=1, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred = classifier.predict(X_test)
results = pd.DataFrame({"Prediction": y_pred, "Actual": y_test}).reset_index(drop=True)
results
# Out:
#      Prediction  Actual
# 0             1       1
# 1             1       0
# 2             1       1
# 3             1       0
# 4             1       0
# ..          ...     ...
# 129           1       1
# 130           1       1
# 131           0       0
# 132           0       0
# 133           0       0
#
# [134 rows x 2 columns]

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, y_pred))
# Out:
# 0.7313432835820896

# %%
matrix = confusion_matrix(y_test, y_pred)
print(matrix)
# Out:
# [[15 26]
#  [10 83]]
